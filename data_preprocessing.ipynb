# %% [markdown]
# # Quickdraw Doodle
# ## Data Preprocessing
# ### Importing the libraries

# %%
import pandas as pd
from os import listdir

# %% [markdown]
# ### Filter unrecognized drawings and unused columns

# %%
input_directory = 'train_simplified/'
output_directory = 'train_simplified_filtered/'
filenames = [e for e in listdir(input_directory) if e[-4:] == '.csv']
for filename in filenames:
    file = pd.read_csv(input_directory + filename)
    number_of_images = len(file)
    number_of_recognized_images = len(file[file['recognized']])
    print(filename+','+str(number_of_images)+','+str(number_of_recognized_images))
    file[file['recognized']][['key_id', 'drawing', 'word']].to_csv(output_directory + filename, index=False)
    del file

# %% [markdown]
# ### Split training set and test set

# %%
input_directory = 'train_simplified_filtered/'
train_output_directory = 'train_simplified/'
test_output_directory = 'test_simplified/'
filenames = [e for e in listdir(input_directory) if e[-4:] == '.csv']
i = 0
for filename in filenames:
    i += 1
    print(i, filename)
    file = pd.read_csv(input_directory + filename)
    test_set = file.sample(frac=1)[:5000]
    test_set.to_csv(test_output_directory + filename, index=False)
    train_set = file[~file['key_id'].isin(test_set['key_id'])]
    train_set.to_csv(train_output_directory + filename, index=False)
    del file

# %% [markdown]
# ### Split training set into smaller files

# %%
input_directory = 'train_simplified/set_t/'
output_directories = []
for i in range(51, 101):
    output_directories.append('train_simplified/set_' + str(i) + '/')
filenames = [e for e in listdir(input_directory) if e[-4:] == '.csv']
file_number = 0
for filename in filenames:
    file_number += 1
    print(file_number, filename)
    file = pd.read_csv(input_directory + filename)
    for i in range(len(output_directories) - 1):
        test_set = file.sample(frac=1/(len(output_directories) - i))
        test_set.to_csv(output_directories[i] + filename, index=False)
        file = file[~file['key_id'].isin(test_set['key_id'])]
    file.to_csv(output_directories[-1] + filename, index=False)
    del file
# Out:
# 1 airplane.csv
# 2 alarm clock.csv
# 3 ambulance.csv
# 4 angel.csv
# 5 animal migration.csv
# 6 ant.csv
# 7 anvil.csv
# 8 apple.csv
# 9 arm.csv
# 10 asparagus.csv
# 11 axe.csv
# 12 backpack.csv
# 13 banana.csv
# 14 bandage.csv
# 15 barn.csv
# 16 baseball bat.csv
# 17 baseball.csv
# 18 basket.csv
# 19 basketball.csv
# 20 bat.csv
# 21 bathtub.csv
# 22 beach.csv
# 23 bear.csv
# 24 beard.csv
# 25 bed.csv
# 26 bee.csv
# 27 belt.csv
# 28 bench.csv
# 29 bicycle.csv
# 30 binoculars.csv
# 31 bird.csv
# 32 birthday cake.csv
# 33 blackberry.csv
# 34 blueberry.csv
# 35 book.csv
# 36 boomerang.csv
# 37 bottlecap.csv
# 38 bowtie.csv
# 39 bracelet.csv
# 40 brain.csv
# 41 bread.csv
# 42 bridge.csv
# 43 broccoli.csv
# 44 broom.csv
# 45 bucket.csv
# 46 bulldozer.csv
# 47 bus.csv
# 48 bush.csv
# 49 butterfly.csv
# 50 cactus.csv
# 51 cake.csv
# 52 calculator.csv
# 53 calendar.csv
# 54 camel.csv
# 55 camera.csv
# 56 camouflage.csv
# 57 campfire.csv
# 58 candle.csv
# 59 cannon.csv
# 60 canoe.csv
# 61 car.csv
# 62 carrot.csv
# 63 castle.csv
# 64 cat.csv
# 65 ceiling fan.csv
# 66 cell phone.csv
# 67 cello.csv
# 68 chair.csv
# 69 chandelier.csv
# 70 church.csv
# 71 circle.csv
# 72 clarinet.csv
# 73 clock.csv
# 74 cloud.csv
# 75 coffee cup.csv
# 76 compass.csv
# 77 computer.csv
# 78 cookie.csv
# 79 cooler.csv
# 80 couch.csv
# 81 cow.csv
# 82 crab.csv
# 83 crayon.csv
# 84 crocodile.csv
# 85 crown.csv
# 86 cruise ship.csv
# 87 cup.csv
# 88 diamond.csv
# 89 dishwasher.csv
# 90 diving board.csv
# 91 dog.csv
# 92 dolphin.csv
# 93 donut.csv
# 94 door.csv
# 95 dragon.csv
# 96 dresser.csv
# 97 drill.csv
# 98 drums.csv
# 99 duck.csv
# 100 dumbbell.csv
# 101 ear.csv
# 102 elbow.csv
# 103 elephant.csv
# 104 envelope.csv
# 105 eraser.csv
# 106 eye.csv
# 107 eyeglasses.csv
# 108 face.csv
# 109 fan.csv
# 110 feather.csv
# 111 fence.csv
# 112 finger.csv
# 113 fire hydrant.csv
# 114 fireplace.csv
# 115 firetruck.csv
# 116 fish.csv
# 117 flamingo.csv
# 118 flashlight.csv
# 119 flip flops.csv
# 120 floor lamp.csv
# 121 flower.csv
# 122 flying saucer.csv
# 123 foot.csv
# 124 fork.csv
# 125 frog.csv
# 126 frying pan.csv
# 127 garden hose.csv
# 128 garden.csv
# 129 giraffe.csv
# 130 goatee.csv
# 131 golf club.csv
# 132 grapes.csv
# 133 grass.csv
# 134 guitar.csv
# 135 hamburger.csv
# 136 hammer.csv
# 137 hand.csv
# 138 harp.csv
# 139 hat.csv
# 140 headphones.csv
# 141 hedgehog.csv
# 142 helicopter.csv
# 143 helmet.csv
# 144 hexagon.csv
# 145 hockey puck.csv
# 146 hockey stick.csv
# 147 horse.csv
# 148 hospital.csv
# 149 hot air balloon.csv
# 150 hot dog.csv
# 151 hot tub.csv
# 152 hourglass.csv
# 153 house plant.csv
# 154 house.csv
# 155 hurricane.csv
# 156 ice cream.csv
# 157 jacket.csv
# 158 jail.csv
# 159 kangaroo.csv
# 160 key.csv
# 161 keyboard.csv
# 162 knee.csv
# 163 ladder.csv
# 164 lantern.csv
# 165 laptop.csv
# 166 leaf.csv
# 167 leg.csv
# 168 light bulb.csv
# 169 lighthouse.csv
# 170 lightning.csv
# 171 line.csv
# 172 lion.csv
# 173 lipstick.csv
# 174 lobster.csv
# 175 lollipop.csv
# 176 mailbox.csv
# 177 map.csv
# 178 marker.csv
# 179 matches.csv
# 180 megaphone.csv
# 181 mermaid.csv
# 182 microphone.csv
# 183 microwave.csv
# 184 monkey.csv
# 185 moon.csv
# 186 mosquito.csv
# 187 motorbike.csv
# 188 mountain.csv
# 189 mouse.csv
# 190 moustache.csv
# 191 mouth.csv
# 192 mug.csv
# 193 mushroom.csv
# 194 nail.csv
# 195 necklace.csv
# 196 nose.csv
# 197 ocean.csv
# 198 octagon.csv
# 199 octopus.csv
# 200 onion.csv
# 201 oven.csv
# 202 owl.csv
# 203 paint can.csv
# 204 paintbrush.csv
# 205 palm tree.csv
# 206 panda.csv
# 207 pants.csv
# 208 paper clip.csv
# 209 parachute.csv
# 210 parrot.csv
# 211 passport.csv
# 212 peanut.csv
# 213 pear.csv
# 214 peas.csv
# 215 pencil.csv
# 216 penguin.csv
# 217 piano.csv
# 218 pickup truck.csv
# 219 picture frame.csv
# 220 pig.csv
# 221 pillow.csv
# 222 pineapple.csv
# 223 pizza.csv
# 224 pliers.csv
# 225 police car.csv
# 226 pond.csv
# 227 pool.csv
# 228 popsicle.csv
# 229 postcard.csv
# 230 potato.csv
# 231 power outlet.csv
# 232 purse.csv
# 233 rabbit.csv
# 234 raccoon.csv
# 235 radio.csv
# 236 rain.csv
# 237 rainbow.csv
# 238 rake.csv
# 239 remote control.csv
# 240 rhinoceros.csv
# 241 river.csv
# 242 roller coaster.csv
# 243 rollerskates.csv
# 244 sailboat.csv
# 245 sandwich.csv
# 246 saw.csv
# 247 saxophone.csv
# 248 school bus.csv
# 249 scissors.csv
# 250 scorpion.csv
# 251 screwdriver.csv
# 252 sea turtle.csv
# 253 see saw.csv
# 254 shark.csv
# 255 sheep.csv
# 256 shoe.csv
# 257 shorts.csv
# 258 shovel.csv
# 259 sink.csv
# 260 skateboard.csv
# 261 skull.csv
# 262 skyscraper.csv
# 263 sleeping bag.csv
# 264 smiley face.csv
# 265 snail.csv
# 266 snake.csv
# 267 snorkel.csv
# 268 snowflake.csv
# 269 snowman.csv
# 270 soccer ball.csv
# 271 sock.csv
# 272 speedboat.csv
# 273 spider.csv
# 274 spoon.csv
# 275 spreadsheet.csv
# 276 square.csv
# 277 squiggle.csv
# 278 squirrel.csv
# 279 stairs.csv
# 280 star.csv
# 281 steak.csv
# 282 stereo.csv
# 283 stethoscope.csv
# 284 stitches.csv
# 285 stop sign.csv
# 286 stove.csv
# 287 strawberry.csv
# 288 streetlight.csv
# 289 string bean.csv
# 290 submarine.csv
# 291 suitcase.csv
# 292 sun.csv
# 293 swan.csv
# 294 sweater.csv
# 295 swing set.csv
# 296 sword.csv
# 297 t-shirt.csv
# 298 table.csv
# 299 teapot.csv
# 300 teddy-bear.csv
# 301 telephone.csv
# 302 television.csv
# 303 tennis racquet.csv
# 304 tent.csv
# 305 The Eiffel Tower.csv
# 306 The Great Wall of China.csv
# 307 The Mona Lisa.csv
# 308 tiger.csv
# 309 toaster.csv
# 310 toe.csv
# 311 toilet.csv
# 312 tooth.csv
# 313 toothbrush.csv
# 314 toothpaste.csv
# 315 tornado.csv
# 316 tractor.csv
# 317 traffic light.csv
# 318 train.csv
# 319 tree.csv
# 320 triangle.csv
# 321 trombone.csv
# 322 truck.csv
# 323 trumpet.csv
# 324 umbrella.csv
# 325 underwear.csv
# 326 van.csv
# 327 vase.csv
# 328 violin.csv
# 329 washing machine.csv
# 330 watermelon.csv
# 331 waterslide.csv
# 332 whale.csv
# 333 wheel.csv
# 334 windmill.csv
# 335 wine bottle.csv
# 336 wine glass.csv
# 337 wristwatch.csv
# 338 yoga.csv
# 339 zebra.csv
# 340 zigzag.csv

# %% [markdown]
# ### Split test set into smaller files

# %%
input_directory = 'test_simplified/merged/'
output_directories = ['test_simplified/set_1/', 'test_simplified/set_2/', 'test_simplified/set_3/', 'test_simplified/set_4/', 'test_simplified/set_5/']
filenames = [e for e in listdir(input_directory) if e[-4:] == '.csv']
file_number = 0
for filename in filenames:
    file_number += 1
    print(file_number, filename)
    file = pd.read_csv(input_directory + filename)
    for i in range(len(output_directories) - 1):
        test_set = file.sample(frac=1/(len(output_directories) - i))
        test_set.to_csv(output_directories[i] + filename, index=False)
        file = file[~file['key_id'].isin(test_set['key_id'])]
    file.to_csv(output_directories[-1] + filename, index=False)
    del file

# %% [markdown]
# ### Merge files

# %%
input_directories = []
for i in range(1, 11):
    input_directories.append('train_simplified/set_'+str(i)+'/')
# input_directories = ['test_simplified/set_1/', 'test_simplified/set_2/', 'test_simplified/set_3/', 'test_simplified/set_4/', 'test_simplified/set_5/']
output_directory = 'train_simplified_merged/set_1/'
filenames = [e for e in listdir(input_directories[0]) if e[-4:] == '.csv']
file_number = 0
for filename in filenames:
    file_number += 1
    print(file_number, filename)
    data = []
    for directory in input_directories:
        data.append(pd.read_csv(directory + filename))
    pd.concat(data).to_csv(output_directory + filename, index=False)
    del data
# Out:
# 1 airplane.csv
# 2 alarm clock.csv
# 3 ambulance.csv
# 4 angel.csv
# 5 animal migration.csv
# 6 ant.csv
# 7 anvil.csv
# 8 apple.csv
# 9 arm.csv
# 10 asparagus.csv
# 11 axe.csv
# 12 backpack.csv
# 13 banana.csv
# 14 bandage.csv
# 15 barn.csv
# 16 baseball bat.csv
# 17 baseball.csv
# 18 basket.csv
# 19 basketball.csv
# 20 bat.csv
# 21 bathtub.csv
# 22 beach.csv
# 23 bear.csv
# 24 beard.csv
# 25 bed.csv
# 26 bee.csv
# 27 belt.csv
# 28 bench.csv
# 29 bicycle.csv
# 30 binoculars.csv
# 31 bird.csv
# 32 birthday cake.csv
# 33 blackberry.csv
# 34 blueberry.csv
# 35 book.csv
# 36 boomerang.csv
# 37 bottlecap.csv
# 38 bowtie.csv
# 39 bracelet.csv
# 40 brain.csv
# 41 bread.csv
# 42 bridge.csv
# 43 broccoli.csv
# 44 broom.csv
# 45 bucket.csv
# 46 bulldozer.csv
# 47 bus.csv
# 48 bush.csv
# 49 butterfly.csv
# 50 cactus.csv
# 51 cake.csv
# 52 calculator.csv
# 53 calendar.csv
# 54 camel.csv
# 55 camera.csv
# 56 camouflage.csv
# 57 campfire.csv
# 58 candle.csv
# 59 cannon.csv
# 60 canoe.csv
# 61 car.csv
# 62 carrot.csv
# 63 castle.csv
# 64 cat.csv
# 65 ceiling fan.csv
# 66 cell phone.csv
# 67 cello.csv
# 68 chair.csv
# 69 chandelier.csv
# 70 church.csv
# 71 circle.csv
# 72 clarinet.csv
# 73 clock.csv
# 74 cloud.csv
# 75 coffee cup.csv
# 76 compass.csv
# 77 computer.csv
# 78 cookie.csv
# 79 cooler.csv
# 80 couch.csv
# 81 cow.csv
# 82 crab.csv
# 83 crayon.csv
# 84 crocodile.csv
# 85 crown.csv
# 86 cruise ship.csv
# 87 cup.csv
# 88 diamond.csv
# 89 dishwasher.csv
# 90 diving board.csv
# 91 dog.csv
# 92 dolphin.csv
# 93 donut.csv
# 94 door.csv
# 95 dragon.csv
# 96 dresser.csv
# 97 drill.csv
# 98 drums.csv
# 99 duck.csv
# 100 dumbbell.csv
# 101 ear.csv
# 102 elbow.csv
# 103 elephant.csv
# 104 envelope.csv
# 105 eraser.csv
# 106 eye.csv
# 107 eyeglasses.csv
# 108 face.csv
# 109 fan.csv
# 110 feather.csv
# 111 fence.csv
# 112 finger.csv
# 113 fire hydrant.csv
# 114 fireplace.csv
# 115 firetruck.csv
# 116 fish.csv
# 117 flamingo.csv
# 118 flashlight.csv
# 119 flip flops.csv
# 120 floor lamp.csv
# 121 flower.csv
# 122 flying saucer.csv
# 123 foot.csv
# 124 fork.csv
# 125 frog.csv
# 126 frying pan.csv
# 127 garden hose.csv
# 128 garden.csv
# 129 giraffe.csv
# 130 goatee.csv
# 131 golf club.csv
# 132 grapes.csv
# 133 grass.csv
# 134 guitar.csv
# 135 hamburger.csv
# 136 hammer.csv
# 137 hand.csv
# 138 harp.csv
# 139 hat.csv
# 140 headphones.csv
# 141 hedgehog.csv
# 142 helicopter.csv
# 143 helmet.csv
# 144 hexagon.csv
# 145 hockey puck.csv
# 146 hockey stick.csv
# 147 horse.csv
# 148 hospital.csv
# 149 hot air balloon.csv
# 150 hot dog.csv
# 151 hot tub.csv
# 152 hourglass.csv
# 153 house plant.csv
# 154 house.csv
# 155 hurricane.csv
# 156 ice cream.csv
# 157 jacket.csv
# 158 jail.csv
# 159 kangaroo.csv
# 160 key.csv
# 161 keyboard.csv
# 162 knee.csv
# 163 ladder.csv
# 164 lantern.csv
# 165 laptop.csv
# 166 leaf.csv
# 167 leg.csv
# 168 light bulb.csv
# 169 lighthouse.csv
# 170 lightning.csv
# 171 line.csv
# 172 lion.csv
# 173 lipstick.csv
# 174 lobster.csv
# 175 lollipop.csv
# 176 mailbox.csv
# 177 map.csv
# 178 marker.csv
# 179 matches.csv
# 180 megaphone.csv
# 181 mermaid.csv
# 182 microphone.csv
# 183 microwave.csv
# 184 monkey.csv
# 185 moon.csv
# 186 mosquito.csv
# 187 motorbike.csv
# 188 mountain.csv
# 189 mouse.csv
# 190 moustache.csv
# 191 mouth.csv
# 192 mug.csv
# 193 mushroom.csv
# 194 nail.csv
# 195 necklace.csv
# 196 nose.csv
# 197 ocean.csv
# 198 octagon.csv
# 199 octopus.csv
# 200 onion.csv
# 201 oven.csv
# 202 owl.csv
# 203 paint can.csv
# 204 paintbrush.csv
# 205 palm tree.csv
# 206 panda.csv
# 207 pants.csv
# 208 paper clip.csv
# 209 parachute.csv
# 210 parrot.csv
# 211 passport.csv
# 212 peanut.csv
# 213 pear.csv
# 214 peas.csv
# 215 pencil.csv
# 216 penguin.csv
# 217 piano.csv
# 218 pickup truck.csv
# 219 picture frame.csv
# 220 pig.csv
# 221 pillow.csv
# 222 pineapple.csv
# 223 pizza.csv
# 224 pliers.csv
# 225 police car.csv
# 226 pond.csv
# 227 pool.csv
# 228 popsicle.csv
# 229 postcard.csv
# 230 potato.csv
# 231 power outlet.csv
# 232 purse.csv
# 233 rabbit.csv
# 234 raccoon.csv
# 235 radio.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7decfc09fc0d> in <module>()
#      11     data = []
#      12     for directory in input_directories:
# ---> 13         data.append(pd.read_csv(directory + filename))
#      14     pd.concat(data).to_csv(output_directory + filename, index=False)
#      15     del data
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     453
#     454     try:
# --> 455         data = parser.read(nrows)
#     456     finally:
#     457         parser.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1067                 raise ValueError('skipfooter not supported for iteration')
#    1068
# -> 1069         ret = self._engine.read(nrows)
#    1070
#    1071         if self.options.get('as_recarray'):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1837     def read(self, nrows=None):
#    1838         try:
# -> 1839             data = self._reader.read(nrows)
#    1840         except StopIteration:
#    1841             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_integer_dtype(arr_or_dtype)
#     775
#     776
# --> 777 def is_integer_dtype(arr_or_dtype):
#     778     """
#     779     Check whether the provided array or dtype is of an integer dtype.
#
# KeyboardInterrupt:
